# %% [markdown]
# # Pyöröovi-syndrooman ennustemallin notebook - hyödyntäen DSX ja Python.
#
# Copyright (c) 2018 IBM Corp. - Summary: This notebook builds a predictive model for predicting hospital readmissions within 30 days of discharge. - Feedback is welcome and appreciated.
#
#
# <div class="alert alert-block alert-info"><b>(1) Data Understanding </b>(Understanding Attributes)</b><br><br> Data Source :
#  __[UCI ML Open data](https://archive.ics.uci.edu/ml/datasets/Diabetes+130-US+hospitals+for+years+1999-2008)__  Understanding Attribitues : __[Table data](https://dataplatform.ibm.com/projects/0b3597b6-2501-4f92-877c-a15b182c413d/data-assets/f462c71b-65d6-4cd0-9bf9-68b2117e644a/?context=analytics)__</div>

# %% [markdown]
# #### Data imports

# %%
# Matplotlib is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms
# %matplotlib inline 

# Imports from the base Python Libraries
import time
import requests
from collections import Counter
from StringIO import StringIO

# Imports for the Dataframe handling libraries
import pandas as pd
import numpy as np

# Selective Imports for the Machine Learning Library
from sklearn import preprocessing
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import ExtraTreesClassifier
from sklearn import metrics

# %%
from bokeh.io import output_notebook
output_notebook()

from bokeh.charts import Bar,  show, Scatter
from bokeh.charts import defaults
defaults.width = 800
defaults.height = 400
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="16d39fd9-1ea2-46a3-a24e-a207bd068efd">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# #### Load the data into a Pandas DataFrame

# %%
# Print the Start time
print 'Start: ',time.asctime()

def load_csv_to_df(file_url):
    return pd.read_csv(StringIO((requests.get(file_url)).text), sep=",")

train_url = 'https://ibm.box.com/shared/static/4ix1ioo1cuy8aocz8koq46v084ad3b1m.csv'
test_url = ''
    
# Here we read the both URLs into DataFrame objects.  Note we will only use df_train in this notebook.   
# By the way, the CSV file includes the Column Header names in the first row and Pandas handles these properly.
# Also, data types will be inferred as best as possible.  (Pandas allows columns to be mixed data types, these column will be typed as 'object')
    
df_train = load_csv_to_df(train_url)
#df_test = load_csv_to_df(test_url)

# print the shape of the dataframes.  (Number of Rows, Number of Columns)

print np.shape(df_train)
#print np.shape(df_test)

# print the end time to see how long the load took
print 'End: ',time.asctime()
# Out:
# Start:  Mon Feb 12 06:48:40 2018
# (101766, 50)
# End:  Mon Feb 12 06:48:45 2018

# %% [markdown]
# #### Let's take a look at the raw data:

# %%
df_train.head(10)
# Out:
#    encounter_id  patient_nbr             race  gender       age weight  \
# 0       2278392      8222157        Caucasian  Female    [0-10)      ?
# 1        149190     55629189        Caucasian  Female   [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3        500364     82442376        Caucasian    Male   [30-40)      ?
# 4         16680     42519267        Caucasian    Male   [40-50)      ?
# 5         35754     82637451        Caucasian    Male   [50-60)      ?
# 6         55842     84259809        Caucasian    Male   [60-70)      ?
# 7         63768    114882984        Caucasian    Male   [70-80)      ?
# 8         12522     48330783        Caucasian  Female   [80-90)      ?
# 9         15738     63555939        Caucasian  Female  [90-100)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
# 5                  2                         1                    2
# 6                  3                         1                    2
# 7                  1                         1                    7
# 8                  2                         1                    4
# 9                  3                         3                    4
#
#    time_in_hospital    ...     citoglipton insulin  glyburide-metformin  \
# 0                 1    ...              No      No                   No
# 1                 3    ...              No      Up                   No
# 2                 2    ...              No      No                   No
# 3                 2    ...              No      Up                   No
# 4                 1    ...              No  Steady                   No
# 5                 3    ...              No  Steady                   No
# 6                 4    ...              No  Steady                   No
# 7                 5    ...              No      No                   No
# 8                13    ...              No  Steady                   No
# 9                12    ...              No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
# 5                   No                        No                       No
# 6                   No                        No                       No
# 7                   No                        No                       No
# 8                   No                        No                       No
# 9                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
# 5                      No      No         Yes        >30
# 6                      No      Ch         Yes         NO
# 7                      No      No         Yes        >30
# 8                      No      Ch         Yes         NO
# 9                      No      Ch         Yes         NO
#
# [10 rows x 50 columns]

# %%
(df_train[df_train['readmitted']=='<30']).head(10)
# Out:
#      encounter_id  patient_nbr             race  gender      age weight  \
# 11          36900     77391171  AfricanAmerican    Male  [60-70)      ?
# 12          40926     85504905        Caucasian  Female  [40-50)      ?
# 16          77076     92519352  AfricanAmerican    Male  [50-60)      ?
# 46         486156     86240259        Caucasian  Female  [70-80)      ?
# 50         550098     21820806  AfricanAmerican    Male  [50-60)      ?
# 68         796152     23043240        Caucasian  Female  [50-60)      ?
# 70         870294     95075649        Caucasian  Female  [70-80)      ?
# 77        1050294    100113975        Caucasian  Female  [60-70)      ?
# 114       1810752      6915888        Caucasian    Male  [70-80)      ?
# 116       1881372      3115566        Caucasian    Male  [60-70)      ?
#
#      admission_type_id  discharge_disposition_id  admission_source_id  \
# 11                   2                         1                    4
# 12                   1                         3                    7
# 16                   1                         1                    7
# 46                   3                         5                    4
# 50                   2                         1                    2
# 68                   2                         1                    4
# 70                   1                         6                    7
# 77                   3                         3                    1
# 114                  1                         3                    7
# 116                  1                         2                    7
#
#      time_in_hospital    ...     citoglipton insulin  glyburide-metformin  \
# 11                  7    ...              No  Steady                   No
# 12                  7    ...              No    Down                   No
# 16                  4    ...              No  Steady                   No
# 46                  9    ...              No    Down                   No
# 50                  4    ...              No      No                   No
# 68                  2    ...              No  Steady                   No
# 70                  7    ...              No      No                   No
# 77                  3    ...              No      Up                   No
# 114                14    ...              No      Up                   No
# 116                 4    ...              No  Steady                   No
#
#      glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 11                    No                        No                       No
# 12                    No                        No                       No
# 16                    No                        No                       No
# 46                    No                        No                       No
# 50                    No                        No                       No
# 68                    No                        No                       No
# 70                    No                        No                       No
# 77                    No                        No                       No
# 114                   No                        No                       No
# 116                   No                        No                       No
#
#      metformin-pioglitazone  change diabetesMed readmitted
# 11                       No      Ch         Yes        <30
# 12                       No      Ch         Yes        <30
# 16                       No      Ch         Yes        <30
# 46                       No      Ch         Yes        <30
# 50                       No      No          No        <30
# 68                       No      No         Yes        <30
# 70                       No      No          No        <30
# 77                       No      Ch         Yes        <30
# 114                      No      Ch         Yes        <30
# 116                      No      No         Yes        <30
#
# [10 rows x 50 columns]

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>(2) Data Preparation</b>
# <br>...Data Cleaning (format,merge,filter out,replace missing values.. etc)
# <br>...Feature Engineering (brainstorming,deciding create/remov,criteria selec,creat new feature,study impact of model goodness..)
# <br>... ...Univarate Selection (statistical test to select those features haveing strongest relationship for output)
# <br>... ...Recursive Feature Elimination (recursively removing attributes and building a model on those attributes that remain.)
# <br>... ...PCA (Principal Component Analysis (or PCA) uses linear algebra to transform the dataset into a compressed form)
# <br>... ...Feature Importance (Bagged decision trees like Random Forest and Extra Trees can be used to estimate the importance of features.)
# <br>...Fitting to Classifier (normalize data set ranges, attribute scaking (z-scale), derieve new predictors)
# <br>...Descriptive Statistics  (provide meaningful summaries of data interest (mean,median,correlation, variance,skewness,contogency..etc)
# <br>...Clustering (try to find idea of similarity in data - explatory analysis to understand structure of data. for entire data set, PCA, dim reduction - tech metric based,distribution based.. etc)
# <br>...Sampling... etc</div>
#
#
# #### Show all the columns and which columns have missing data

# %%
# Loop through the column names in the df_train dataframe and count how many cells for each column are found to be null 

print "Missing values by column"
for col in df_train.columns:
    print col, len(df_train[pd.isnull(df_train[col])])
# Out:
# Missing values by column
# encounter_id 0
# patient_nbr 0
# race 0
# gender 0
# age 0
# weight 0
# admission_type_id 0
# discharge_disposition_id 0
# admission_source_id 0
# time_in_hospital 0
# payer_code 0
# medical_specialty 0
# num_lab_procedures 0
# num_procedures 0
# num_medications 0
# number_outpatient 0
# number_emergency 0
# number_inpatient 0
# diag_1 0
# diag_2 0
# diag_3 0
# number_diagnoses 0
# max_glu_serum 0
# A1Cresult 0
# metformin 0
# repaglinide 0
# nateglinide 0
# chlorpropamide 0
# glimepiride 0
# acetohexamide 0
# glipizide 0
# glyburide 0
# tolbutamide 0
# pioglitazone 0
# rosiglitazone 0
# acarbose 0
# miglitol 0
# troglitazone 0
# tolazamide 0
# examide 0
# citoglipton 0
# insulin 0
# glyburide-metformin 0
# glipizide-metformin 0
# glimepiride-pioglitazone 0
# metformin-rosiglitazone 0
# metformin-pioglitazone 0
# change 0
# diabetesMed 0
# readmitted 0

# %% [markdown]
# #### Handle Missing Values

# %%
#Not needed for this dataset

#df_train.fillna('x', inplace=True)
#df_test.fillna('x', inplace=True)

# %% [markdown]
# #### Change from 3 class problem to 2 class problem
#
# 1. Readmitted < 30 Days
# 1. Readmitted > 30 Days
# 1. Not Readmitted
#
# #### Note This change only is effective in RAM.  it does not change the DB.
#
#
# Set readmitted to 1/0

# %%
df_train['readmitted'] = df_train['readmitted'].apply( lambda x: 1 if x == '<30' else 0)

# %% [markdown]
# #### This is highly imbalanced data, that is, many more not readmitted than readmitted.
#
# Depending on choice of algorithm and other aspects of the dataset, somtimes it helps to rebalance the dataset.

# %%
# Downsample the df_train to balance readmitted 1/0.  

DOWNSAMPLE = 1  # need to turn on if using algos which are not robust to unbalanced data (most algos)

if DOWNSAMPLE == 1:
    
    df_positives = (df_train[df_train['readmitted'] == 1]).copy()
    df_negatives = (df_train[df_train['readmitted'] == 0]).sample(len(df_positives), axis=0)
    df_train = pd.concat((df_positives, df_negatives), axis=0)
    print np.shape(df_train)
# Out:
# (22714, 50)

# %% [markdown]
# #### Remove Columns which are unique to each patient (will have little predictive value)

# %%
# Hard code the ones we know we want to drop.  Then to easily remove these from the list of all columns, 
# get the columns from the DataFrame, convert both lists to sets (for easy subtraction), convert back to a list as keep_cols. 
# This has one slightly unwanted side effect, that is it re-orders the columns.  This is a side effect of converting to set.


print 'Before: ',df_train.columns.values
drop_cols = ['encounter_id', 'patient_nbr', 'weight',  ]
keep_cols = list(set(df_train.columns) - set(drop_cols))
#print keep_cols

df_train = df_train[keep_cols]
print 'After: ',df_train.columns.values
# Out:
# Before:  ['encounter_id' 'patient_nbr' 'race' 'gender' 'age' 'weight'
#  'admission_type_id' 'discharge_disposition_id' 'admission_source_id'
#  'time_in_hospital' 'payer_code' 'medical_specialty' 'num_lab_procedures'
#  'num_procedures' 'num_medications' 'number_outpatient' 'number_emergency'
#  'number_inpatient' 'diag_1' 'diag_2' 'diag_3' 'number_diagnoses'
#  'max_glu_serum' 'A1Cresult' 'metformin' 'repaglinide' 'nateglinide'
#  'chlorpropamide' 'glimepiride' 'acetohexamide' 'glipizide' 'glyburide'
#  'tolbutamide' 'pioglitazone' 'rosiglitazone' 'acarbose' 'miglitol'
#  'troglitazone' 'tolazamide' 'examide' 'citoglipton' 'insulin'
#  'glyburide-metformin' 'glipizide-metformin' 'glimepiride-pioglitazone'
#  'metformin-rosiglitazone' 'metformin-pioglitazone' 'change' 'diabetesMed'
#  'readmitted']
# After:  ['chlorpropamide' 'repaglinide' 'payer_code' 'number_diagnoses'
#  'num_medications' 'readmitted' 'rosiglitazone' 'miglitol' 'glipizide'
#  'discharge_disposition_id' 'citoglipton' 'admission_source_id'
#  'medical_specialty' 'num_lab_procedures' 'acarbose' 'diag_1'
#  'number_outpatient' 'glyburide' 'metformin' 'A1Cresult' 'pioglitazone'
#  'time_in_hospital' 'glyburide-metformin' 'tolbutamide' 'glimepiride'
#  'troglitazone' 'metformin-rosiglitazone' 'max_glu_serum' 'diabetesMed'
#  'metformin-pioglitazone' 'number_inpatient' 'number_emergency'
#  'acetohexamide' 'change' 'glimepiride-pioglitazone' 'age' 'examide'
#  'nateglinide' 'tolazamide' 'race' 'glipizide-metformin' 'insulin' 'gender'
#  'num_procedures' 'diag_2' 'diag_3' 'admission_type_id']

# %% [markdown]
# #### Let's take another look at the data to see where we are

# %%
df_train.head()
# Out:
#    chlorpropamide repaglinide payer_code  number_diagnoses  num_medications  \
# 11             No          No          ?                 7               11
# 12             No          Up          ?                 8               15
# 16             No          No          ?                 8               17
# 46             No          No          ?                 7               16
# 50             No          No          ?                 9               14
#
#     readmitted rosiglitazone miglitol glipizide  discharge_disposition_id  \
# 11           1            No       No        No                         1
# 12           1            No       No        No                         3
# 16           1            No       No    Steady                         1
# 46           1            No       No        No                         5
# 50           1            No       No        No                         1
#
#           ...        nateglinide  tolazamide             race  \
# 11        ...                 No          No  AfricanAmerican
# 12        ...                 No          No        Caucasian
# 16        ...                 No          No  AfricanAmerican
# 46        ...                 No          No        Caucasian
# 50        ...                 No          No  AfricanAmerican
#
#     glipizide-metformin insulin  gender  num_procedures  diag_2  diag_3  \
# 11                   No  Steady    Male               0     288     197
# 12                   No    Down  Female               0  250.43   250.6
# 16                   No  Steady    Male               4     411     414
# 46                   No    Down  Female               3     427  250.01
# 50                   No      No    Male               1     198     197
#
#    admission_type_id
# 11                 2
# 12                 1
# 16                 1
# 46                 3
# 50                 2
#
# [5 rows x 47 columns]

# %% [markdown]
# #### Replace String Categorical values with numbers using LabelEncoder

# %%
encoder = preprocessing.LabelEncoder()

categoricals =['race','gender','age','payer_code','medical_specialty','diag_1','diag_2','diag_3','max_glu_serum','A1Cresult','metformin','repaglinide','nateglinide','chlorpropamide','glimepiride','acetohexamide','glipizide'
,'glyburide','tolbutamide','pioglitazone','rosiglitazone','acarbose','miglitol','troglitazone','tolazamide','examide','citoglipton','insulin','glyburide-metformin','glipizide-metformin','glimepiride-pioglitazone'
,'metformin-rosiglitazone','metformin-pioglitazone','change','diabetesMed','discharge_disposition_id','admission_type_id','admission_source_id']

for col in categoricals: 
    df_train[col] = encoder.fit_transform(df_train[col])

# %% [markdown]
# #### Let's take one more look at the data after cleaning and encoding...

# %%
df_train.head(5)
# Out:
#     chlorpropamide  repaglinide  payer_code  number_diagnoses  \
# 11               0            1           0                 7
# 12               0            3           0                 8
# 16               0            1           0                 8
# 46               0            1           0                 7
# 50               0            1           0                 9
#
#     num_medications  readmitted  rosiglitazone  miglitol  glipizide  \
# 11               11           1              1         1          1
# 12               15           1              1         1          1
# 16               17           1              1         1          2
# 46               16           1              1         1          1
# 50               14           1              1         1          1
#
#     discharge_disposition_id        ...          nateglinide  tolazamide  \
# 11                         0        ...                    1           0
# 12                         2        ...                    1           0
# 16                         0        ...                    1           0
# 46                         4        ...                    1           0
# 50                         0        ...                    1           0
#
#     race  glipizide-metformin  insulin  gender  num_procedures  diag_2  \
# 11     1                    0        2       1               0     112
# 12     3                    0        0       0               0      73
# 16     1                    0        2       1               4     185
# 46     3                    0        0       0               3     199
# 50     1                    0        1       1               1      32
#
#     diag_3  admission_type_id
# 11      31                  1
# 12      75                  0
# 16     198                  0
# 46      58                  2
# 50      31                  1
#
# [5 rows x 47 columns]

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>(3) Modeling & Evaluation</b>
# <br>Data Splitting (test (30),train (70) (validatin))
# <br>Machine Learning ( build model with train testset (learning!) , test model in test data set - compare & dep)
# <br>Algorithms (linera regression,logistic regression,decision tree, random forest, ensemble, SVA, Naive Bayes etc..)
# <br> <b> Model Evaluation</b>
# <br>Prediction Accuracy
# <br>Confusion Matrix( Examin Confusion Matrix max TP ja TN ja min FP ja FN results)
# <br>Cross Validation (k-fold cross validation - eri dataseteillä alg testausta)
# <br>Feature Importance
# </div>

# %% [markdown]
# #### Get ready to do the training.

# %%
# Save the Targets in a separate vector, then drop from the training data
y_all = df_train['readmitted']
X_all = df_train.drop('readmitted', axis=1, inplace=False)

# Use the convenience function to split the entire data into 4 dataframes. 
X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.3, random_state=39)

# %% [markdown]
# #### Almost ready to train.  Let's define two common functions used in the training process
# Here we declare two functions we'll re-use in our ML iterations.

# %%
# run_and_test_classifier does what is sounds like
# Parameters are the instantiated classifier object and the 4 dataframes mentioned just above.

def run_and_test_classifier(classifier, X_train, y_train, X_test, y_test):
    print
    print 'Start: ',time.asctime()
    print
    print classifier
    
    # fit is the method to perform the training part of the process, 
    # we provide both the input training matrix (X_train) and the target answers (y_train) 
    classifier.fit(X_train, y_train)
    
    # the predict method returns predictions as 1 or 0 
    y_pred = classifier.predict(X_test)
    
    # the predict_proba returns predictions as a probabilities matrix, that is, a probailities vector for each row in the X_test matrix 
    y_probs = classifier.predict_proba(X_test)   
    # Extract just the probabilies for Survived==1 
    y_probs = y_probs[:,1]    # take all rows, but keep only second column, that is, the probability of survived = 1 

    # Call the calc_classifier_stats to print basic statistics on the quality of our classifiers for comparison
    calc_classifier_stats(y_test, y_pred, y_probs)

    # Some classifier algorithms, allow retrieval of "Feature Importances".  Which columns are most useful in prediction.
    # Loop through the columns printing the name of the column and the importance value for that column
    print
    print
    print
    print 'Feature Importances:'
    print '===================='
    print
    print
    importances = []
    
   # feature_importance = gbm.feature_importances_
   # feature_importance = 100.0 * (feature_importance / feature_importance.max())
   # sorted_idx = np.argsort(feature_importance)[::-1]
 # feature_importance[sorted_idx]
    
    try:
        imps = classifier.feature_importances_ 
        for col, imp in zip(X_train.columns, imps):
            print col.ljust(20), "\t " ,str(imp).rjust(10)
            importances.append([col,imp])
        df_imps = pd.DataFrame(importances,columns=['Feature','Importance'])
        show(Bar(df_imps, 
        label='Feature', 
        values='Importance',
        title="Feature Importance", 
        xlabel='Feature', 
        ylabel='Importance',
        legend=None, 
        tools=''))
    except AttributeError:
        pass
    print
    print 'End: ',time.asctime()
    return  y_pred, y_probs



# The calc_classifier_stats method calculates various statistics about the quality of the classifier
# Paramters are: y_test (true values), y_pred (0/1 values), y_probs (probabilities of Survival values)
# The main thing we will look at is the ROC-AUC which is the Area Under the Curve of the Receiver Operating Characteristics
# Although there is complicated math underlying it, the ROC-AUC is very easy to understand and makes it easy to compare different models.


def plot_roc(y_test, y_probs):
             
    print 'SCORE: ROC AUC '
    print '==========================================='
    print metrics.roc_auc_score(y_test, y_probs) 
    print
    print
    import matplotlib.pyplot as plt
    false_positive_rate, true_positive_rate, thresholds = metrics.roc_curve(y_test, y_probs) 
    roc_auc = metrics.auc(false_positive_rate, true_positive_rate)
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate, 'b',
    label='ROC Area Under Curve = %0.4f'% roc_auc)
    plt.legend(loc='lower right')
    plt.plot([0,1],[0,1],'r--')
    plt.xlim([0.0,1.0])
    plt.ylim([0.0,1.05])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

def calc_classifier_stats(y_test, y_pred, y_probs):
    print 'Classification Results'
    print
    print 
    plot_roc(y_test, y_probs)
    print
    print
    print
    print 'Confusion Matrix'
    print '==========================================='
    cm = metrics.confusion_matrix(y_test, y_pred)
    print 'True Pos  \t| False Neg'
    print cm[0,0],'\t\t|', cm[0,1]
    print '------------------------------'
    print 'False Pos \t| True Neg'
    print cm[1,0],  '\t\t|', cm[1,1]
    print 
    print
    print
    print 'Classification Report'
    print '==========================================='
    print metrics.classification_report(y_test, y_pred)
    print
    
    return

# %% [markdown]
# #### Now We Are Ready for Training

# %% [markdown]
# <div class="alert alert-block alert-success"><b>First attempt:  Start with a Basic Decision Tree</b> Let's first use a DecisionTreeClassifier (a weak classifier) to see where we stand.  </div>

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion='gini', splitter='best', max_depth=None, 
                                    min_samples_split=2, min_samples_leaf=1, 
                                    min_weight_fraction_leaf=0.0, 
                                    max_features=None, random_state=13, max_leaf_nodes=None, class_weight=None, presort=False)
y_pred, y_probs = run_and_test_classifier(classifier, X_train,y_train,X_test, y_test)

df_ens = pd.DataFrame([])
df_ens['DecisionTree'] = y_probs

print np.shape(df_ens)
# Out:
# Start:  Mon Feb 12 06:50:47 2018
#
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=13,
#             splitter='best')
# Classification Results
#
#
# SCORE: ROC AUC
# ===========================================
# 0.542656366298
# Confusion Matrix
# ===========================================
# True Pos  	| False Neg
# 1833 		| 1589
# ------------------------------
# False Pos 	| True Neg
# 1528 		| 1865
#
#
#
# Classification Report
# ===========================================
#              precision    recall  f1-score   support
#
#           0       0.55      0.54      0.54      3422
#           1       0.54      0.55      0.54      3393
#
# avg / total       0.54      0.54      0.54      6815
#
#
#
#
#
# Feature Importances:
# ====================
#
#
# chlorpropamide       	  0.000441519612837
# repaglinide          	  0.00185497600863
# payer_code           	  0.0311965688363
# number_diagnoses     	  0.029969662005
# num_medications      	  0.0709816364708
# rosiglitazone        	  0.00571188541093
# miglitol             	         0.0
# glipizide            	  0.0133495532259
# discharge_disposition_id 	  0.0459454903309
# citoglipton          	         0.0
# admission_source_id  	  0.0174412854638
# medical_specialty    	  0.0350443559627
# num_lab_procedures   	  0.105911907966
# acarbose             	  0.000193649158899
# diag_1               	  0.09764195977
# number_outpatient    	  0.0178617295535
# glyburide            	  0.011398091324
# metformin            	  0.0150441922407
# A1Cresult            	  0.0165134712528
# pioglitazone         	  0.00403769302551
# time_in_hospital     	  0.0489639784308
# glyburide-metformin  	  0.00137212973239
# tolbutamide          	  0.000167663893756
# glimepiride          	  0.00727116069758
# troglitazone         	         0.0
# metformin-rosiglitazone 	         0.0
# max_glu_serum        	  0.00629389845716
# diabetesMed          	  0.0107176867692
# metformin-pioglitazone 	         0.0
# number_inpatient     	  0.0536524127605
# number_emergency     	  0.0114183979553
# acetohexamide        	  0.000234816388092
# change               	  0.00865545424705
# glimepiride-pioglitazone 	         0.0
# age                  	  0.0433153044611
# examide              	         0.0
# nateglinide          	  0.00235358438978
# tolazamide           	         0.0
# race                 	  0.0155012910046
# glipizide-metformin  	         0.0
# insulin              	  0.0223049333912
# gender               	  0.012166775784
# num_procedures       	  0.0344249332603
# diag_2               	  0.0893768848008
# diag_3               	  0.0904546195173
# admission_type_id    	  0.0208144464404
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7ad86739-b81b-450a-9c9d-a89c12127d60"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("7ad86739-b81b-450a-9c9d-a89c12127d60");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7ad86739-b81b-450a-9c9d-a89c12127d60");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7ad86739-b81b-450a-9c9d-a89c12127d60' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c6035f06-42d3-4c0f-b21e-332835c69915":{"roots":{"references":[{"attributes":{"data_source":{"id":"97bd8d90-44b2-4c9b-a8e8-8d425963e4b8","type":"ColumnDataSource"},"glyph":{"id":"e3b71ed4-fd57-4395-8335-7f09884a0ed4","type":"Rect"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"053376f8-e20a-42ab-9ff3-79caf106dc22","type":"CDSView"}},"id":"3deebd9d-939f-4803-aee8-8d65fb0d8ad2","type":"GlyphRenderer"},{"attributes":{"source":null},"id":"f2fec6da-1fdb-449d-83a1-40962cf7d4b0","type":"CDSView"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0583638c-b955-4113-b6f9-12ad002b8f27","type":"Rect"},{"attributes":{},"id":"281dbf9a-ee72-43d7-ac3b-3f344ccb0f3d","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4ed029ad-b2eb-4ad2-8aaa-eb17c26c193f","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Feature":["discharge_disposition_id"],"chart_index":[{"Feature":"discharge_disposition_id"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.045945490330864494],"label":[{"Feature":"discharge_disposition_id"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["discharge_disposition_id"],"y":[0.022972745165432247]}},"id":"40663773-6d61-4368-aaba-2c12af0f4b93","type":"ColumnDataSource"},{"attributes":{"source":null},"id":"503e4af4-5232-4aef-8498-791ea39cbdaa","type":"CDSView"},{"attributes":{"source":null},"id":"f4b6636e-2b67-4d21-b277-aec6299bfefb","type":"CDSView"},{"attributes":{},"id":"73174119-d85f-415f-80d7-0d3b87007fba","type":"LinearScale"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Feature":["tolazamide"],"chart_index":[{"Feature":"tolazamide"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":[{"Feature":"tolazamide"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["tolazamide"],"y":[0.0]}},"id":"c2a2cf72-02ca-4526-b2b5-09d7ad09c4a5","type":"ColumnDataSource"},{"attributes":{"source":null},"id":"6254f381-0261-4e4a-82ff-c24233bbd28f","type":"CDSView"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7afd247e-6ab5-498b-aedc-402ab39931cc","type":"Rect"},{"attributes":{"data_source":{"id":"f28742f8-d725-40db-9062-4fc1aaf0bc4c","type":"ColumnDataSource"},"glyph":{"id":"3e3a9099-1225-419b-9888-622ec1b1b118","type":"Rect"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"41103cec-2b30-46f7-83d8-9d6b31ad408d","type":"CDSView"}},"id":"a75a1c7a-bc41-466e-8199-1a19a42fbe92","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"09603a12-34a2-4987-a565-267d1bf6a96d","subtype":"Chart","type":"Plot"},"ticker":{"id":"8ca0a43f-8bed-4014-886f-16ac83436c74","type":"BasicTicker"}},"id":"6982a6ed-f739-4882-a5eb-ad6e0e168670","type":"Grid"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Feature":["race"],"chart_index":[{"Feature":"race"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.015501291004572744],"label":[{"Feature":"race"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["race"],"y":[0.007750645502286372]}},"id":"dbd49dcf-95a0-439d-9bf0-dbde2c354c79","type":"ColumnDataSource"},{"attributes":{"source":null},"id":"57cbc1ba-64c4-4c42-b484-cba7ea9e4000","type":"CD ...
# End:  Mon Feb 12 06:50:49 2018
# (6815, 1)

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Second attempt: Switch to a RF Algorithm</b>  </div>

# %%
classifier = ExtraTreesClassifier(n_estimators=500, max_features='auto', n_jobs=-1)
y_pred, y_probs = run_and_test_classifier(classifier, X_train,y_train,X_test, y_test)

df_ens['ExtraTrees1'] = y_probs
print np.shape(df_ens)
# Out:
# Start:  Mon Feb 12 04:45:15 2018
#
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)
# Classification Results
#
#
# SCORE: ROC AUC
# ===========================================
# 0.641141050359
# Confusion Matrix
# ===========================================
# True Pos  	| False Neg
# 2101 		| 1321
# ------------------------------
# False Pos 	| True Neg
# 1396 		| 1997
#
#
#
# Classification Report
# ===========================================
#              precision    recall  f1-score   support
#
#           0       0.60      0.61      0.61      3422
#           1       0.60      0.59      0.60      3393
#
# avg / total       0.60      0.60      0.60      6815
#
#
#
#
#
# Feature Importances:
# ====================
#
#
# chlorpropamide       	  0.000276640610665
# repaglinide          	  0.00472205607963
# payer_code           	  0.0424067972681
# number_diagnoses     	  0.0425443602386
# num_medications      	  0.0574483594095
# rosiglitazone        	  0.010193356772
# miglitol             	  0.00015508677613
# glipizide            	  0.0161670795792
# discharge_disposition_id 	  0.0486447795496
# citoglipton          	         0.0
# admission_source_id  	  0.0290664813779
# medical_specialty    	  0.0433762930467
# num_lab_procedures   	  0.0583151601369
# acarbose             	  0.00111123258563
# diag_1               	  0.05766238475
# number_outpatient    	  0.0271317970168
# glyburide            	  0.0144759105704
# metformin            	  0.017003296127
# A1Cresult            	  0.0231116958099
# pioglitazone         	  0.0112270631054
# time_in_hospital     	  0.0533552022028
# glyburide-metformin  	  0.00239297227199
# tolbutamide          	  0.000130544822919
# glimepiride          	  0.0092124455741
# troglitazone         	         0.0
# metformin-rosiglitazone 	         0.0
# max_glu_serum        	  0.00873056550473
# diabetesMed          	  0.00670820748611
# metformin-pioglitazone 	         0.0
# number_inpatient     	  0.0584410518617
# number_emergency     	  0.022637976305
# acetohexamide        	         0.0
# change               	  0.0130013365415
# glimepiride-pioglitazone 	         0.0
# age                  	  0.0501162300402
# examide              	         0.0
# nateglinide          	  0.00253749606121
# tolazamide           	  0.00019417328586
# race                 	  0.0295246833874
# glipizide-metformin  	         0.0
# insulin              	  0.0243599765414
# gender               	  0.0233726419987
# num_procedures       	  0.0429940852269
# diag_2               	  0.0570736676255
# diag_3               	  0.0569751898623
# admission_type_id    	  0.0332017225897
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d31abe57-cfca-4184-b9ae-5cd1ae1f12f7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("d31abe57-cfca-4184-b9ae-5cd1ae1f12f7");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d31abe57-cfca-4184-b9ae-5cd1ae1f12f7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd31abe57-cfca-4184-b9ae-5cd1ae1f12f7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0b7dae76-4700-495d-b262-75bf4e3772b7":{"roots":{"references":[{"attributes":{"source":null},"id":"8e3f58e1-b947-4048-8d11-6204a4626834","type":"CDSView"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Feature":["troglitazone"],"chart_index":[{"Feature":"troglitazone"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":[{"Feature":"troglitazone"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["troglitazone"],"y":[0.0]}},"id":"6e6401b6-1d2d-4052-a983-18d4e1f34db3","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"341ed0d2-2344-4eac-9a4c-43f73b46ffb5","type":"ColumnDataSource"},"glyph":{"id":"bc342538-858d-44e6-ad45-53d0148c491b","type":"Rect"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"78f13580-99c3-4c9f-a9c7-9d5a65f2d276","type":"CDSView"}},"id":"20e707dd-9061-4359-a2a2-304274982f7a","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cc30be8e-fc4f-4c06-9046-a04339531f2c","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1a1f9463-ef94-422b-adf6-a766df6d8b06","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6e7a6293-184a-4e19-b85b-ec6c9a51bc15","type":"Rect"},{"attributes":{"data_source":{"id":"a44eb500-c829-4994-b218-ed92483c79bf","type":"ColumnDataSource"},"glyph":{"id":"6e7a6293-184a-4e19-b85b-ec6c9a51bc15","type":"Rect"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"56f575bf-7e9b-48c1-865c-ee0b0d3e5552","type":"CDSView"}},"id":"58fe2065-df69-4847-b363-27ef25d1b3e3","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"627d510c-4ce8-4aa3-bdac-2b01a7c8566b","type":"ColumnDataSource"},"glyph":{"id":"ab55a674-53f0-4f82-bce8-d4130d6bc0a0","type":"Rect"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"ae32859a-8ab1-409e-b7b2-dc257eab4d6e","type":"CDSView"}},"id":"41fab620-7574-40ec-8552-dc6755b590ff","type":"GlyphRenderer"},{"attributes":{"callback":null,"factors":["A1Cresult","acarbose","acetohexamide","admission_source_id","admission_type_id","age","change","chlorpropamide","citoglipton","diabetesMed","diag_1","diag_2","diag_3","discharge_disposition_id","examide","gender","glimepiride","glimepiride-pioglitazone","glipizide","glipizide-metformin","glyburide","glyburide-metformin","insulin","max_glu_serum","medical_specialty","metformin","metformin-pioglitazone","metformin-rosiglitazone","miglitol","nateglinide","num_lab_procedures","num_medications","num_procedures","number_diagnoses","number_emergency","number_inpatient","number_outpatient","payer_code","pioglitazone","race","repaglinide","rosiglitazone","time_in_hospital","tolazamide","tolbutamide","troglitazone"]},"id":"605ac923-052c-4a35-869a-8e7daee188ec","type":"FactorRange"},{"attributes":{"source":null},"id":"21dfa61d-06f8-4974-930a-3d6249cf4ba7","type":"CDSView"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"46447dae-c8d4-415b-9e87-d6cc0175a322","type":"Rect"},{"attributes":{"source":null},"id":"77dad9ef-37a9-4098-b02d-f81a1547f694","type":"CDSView"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"d ...
# End:  Mon Feb 12 04:45:22 2018
# (6815, 2)

# %% [markdown]
# #### Remove the weakest columns.  This allows the remaining columns to do a better job

# %%
#remove weak predictors

weak = ['pioglitazone','metformin','glyburide','glipizide','rosiglitazone','diabetesMed','max_glu_serum','glyburide-metformin','glimepiride','repaglinide','nateglinide','troglitazone','acarbose','miglitol','chlorpropamide','citoglipton','tolbutamide','metformin-rosiglitazone','metformin-pioglitazone' ,'acetohexamide', 'glimepiride-pioglitazone',
    'examide', 'tolazamide', 'glipizide-metformin']

print 'Before: ',df_train.columns.values
keep_cols = list(set(X_train.columns) - set(weak))
#print keep_cols

X_train2 = X_train[keep_cols]
X_test2 = X_test[keep_cols]
print 'After: ',X_train2.columns.values
# Out:
# Before:  ['chlorpropamide' 'repaglinide' 'payer_code' 'number_diagnoses'
#  'num_medications' 'readmitted' 'rosiglitazone' 'miglitol' 'glipizide'
#  'discharge_disposition_id' 'citoglipton' 'admission_source_id'
#  'medical_specialty' 'num_lab_procedures' 'acarbose' 'diag_1'
#  'number_outpatient' 'glyburide' 'metformin' 'A1Cresult' 'pioglitazone'
#  'time_in_hospital' 'glyburide-metformin' 'tolbutamide' 'glimepiride'
#  'troglitazone' 'metformin-rosiglitazone' 'max_glu_serum' 'diabetesMed'
#  'metformin-pioglitazone' 'number_inpatient' 'number_emergency'
#  'acetohexamide' 'change' 'glimepiride-pioglitazone' 'age' 'examide'
#  'nateglinide' 'tolazamide' 'race' 'glipizide-metformin' 'insulin' 'gender'
#  'num_procedures' 'diag_2' 'diag_3' 'admission_type_id']
# After:  ['admission_type_id' 'payer_code' 'number_diagnoses' 'num_medications'
#  'admission_source_id' 'num_lab_procedures' 'A1Cresult' 'time_in_hospital'
#  'number_inpatient' 'discharge_disposition_id' 'change' 'gender' 'age'
#  'medical_specialty' 'race' 'number_outpatient' 'insulin'
#  'number_emergency' 'num_procedures' 'diag_2' 'diag_3' 'diag_1']

# %% [markdown]
# #### Let's rerun to see where we stand

# %%
classifier = ExtraTreesClassifier(n_estimators=1000, max_features='auto', n_jobs=-1,  
                                  criterion='entropy',bootstrap=True, oob_score=True)
y_pred, y_probs = run_and_test_classifier(classifier, X_train2,y_train,X_test2, y_test)

df_ens['ExtraTrees2'] = y_probs
print np.shape(df_ens)
# Out:
# Start:  Mon Feb 12 04:46:32 2018
#
# ExtraTreesClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=-1,
#            oob_score=True, random_state=None, verbose=0, warm_start=False)
# Classification Results
#
#
# SCORE: ROC AUC
# ===========================================
# 0.653413024339
# Confusion Matrix
# ===========================================
# True Pos  	| False Neg
# 2128 		| 1294
# ------------------------------
# False Pos 	| True Neg
# 1360 		| 2033
#
#
#
# Classification Report
# ===========================================
#              precision    recall  f1-score   support
#
#           0       0.61      0.62      0.62      3422
#           1       0.61      0.60      0.61      3393
#
# avg / total       0.61      0.61      0.61      6815
#
#
#
#
#
# Feature Importances:
# ====================
#
#
# admission_type_id    	  0.0382329594419
# payer_code           	  0.047898254266
# number_diagnoses     	  0.0471269478747
# num_medications      	  0.0636641074604
# admission_source_id  	  0.0338236345836
# num_lab_procedures   	  0.0643876937783
# A1Cresult            	  0.0266107532653
# time_in_hospital     	  0.0581470897475
# number_inpatient     	  0.0572397451953
# discharge_disposition_id 	  0.0512701963006
# change               	  0.0179777317279
# gender               	  0.026128596757
# age                  	  0.0557452693837
# medical_specialty    	  0.0489530977629
# race                 	  0.0338018484708
# number_outpatient    	  0.031123287508
# insulin              	  0.0345315172103
# number_emergency     	  0.0252130554101
# num_procedures       	  0.0479590872817
# diag_2               	  0.0634672236281
# diag_3               	  0.0629742435782
# diag_1               	  0.0637236593676
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="06307ece-508f-4ca3-9cf6-2e793fbaabc0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("06307ece-508f-4ca3-9cf6-2e793fbaabc0");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("06307ece-508f-4ca3-9cf6-2e793fbaabc0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '06307ece-508f-4ca3-9cf6-2e793fbaabc0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e01e2909-b11b-45c1-a81e-059cf9e18b74":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Feature":["A1Cresult"],"chart_index":[{"Feature":"A1Cresult"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.026610753265331147],"label":[{"Feature":"A1Cresult"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["A1Cresult"],"y":[0.013305376632665573]}},"id":"5360015a-f690-4af8-8c7b-6d3084bb3672","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Feature":["diag_3"],"chart_index":[{"Feature":"diag_3"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.06297424357820332],"label":[{"Feature":"diag_3"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["diag_3"],"y":[0.03148712178910166]}},"id":"8f3e8aa0-ca7e-4db5-ba2c-4fd4ffe2fd42","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"95d5a9a4-ca27-465b-9126-20e0bb3a5866","type":"ColumnDataSource"},"glyph":{"id":"066a80a7-5bd9-4055-85d1-bdd109b9c683","type":"Rect"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"7a0f81e9-3568-4f3e-9f8d-bbb840e22eaa","type":"CDSView"}},"id":"d434687e-c244-4a17-a9b2-3dc974ec0f70","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"90619979-9345-461f-b2e4-26a6ed7d41e8","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Feature":["number_inpatient"],"chart_index":[{"Feature":"number_inpatient"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.057239745195305725],"label":[{"Feature":"number_inpatient"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["number_inpatient"],"y":[0.028619872597652862]}},"id":"0c07d6bb-bc69-4cae-9e1b-72cb0fc5af6f","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"8a8d3611-be09-4963-a54a-fa0a83c4bdec","subtype":"Chart","type":"Plot"},"ticker":{"id":"93d13876-97c5-4217-b27f-f39bad441497","type":"BasicTicker"}},"id":"4f4198a2-1b95-4468-af26-da1a5f23d8f1","type":"Grid"},{"attributes":{"source":null},"id":"290b14b2-2169-4e4a-93ae-4a48771c2ce8","type":"CDSView"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Feature":["race"],"chart_index":[{"Feature":"race"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.03380184847075572],"label":[{"Feature":"race"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["race"],"y":[0.01690092423537786]}},"id":"cae4d78e-b3e2-41a0-a473-e8a76fb95733","type":"ColumnDataSource"},{"attributes":{"axis_label":"Feature","formatter":{"id":"77593108-02bb-495f-88bb-de1612c2bb2a","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"8a8d3611-be09-4963-a54a-fa0a83c4bdec","subtype":"Chart","type":"Plot"},"ticker":{"id":"820ca0f1-4b1d-4a5a-81d3-445f0dbd9256","type":"CategoricalTicker"}},"id":"f32e4eb9-1c80-4505-b1b7-1c5ed0267b9a","type":"CategoricalAxis"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Feature":["number_diagnoses"],"chart_index":[{"Feature":"number_diagnoses"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.04712694787472558],"label":[{"Feature":"number_diagnoses"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["number_diagnoses"],"y":[0.02356347393736279]}},"id":"0391ab45-a730-4f5f-b6f4-b0d062a197bf","type":"ColumnDataSource"},{"attributes":{"source":null},"id":"ee4f7406-6551-49b2-99a5-b518d77af1ef","type":"CDSView"},{"at ...
# End:  Mon Feb 12 04:46:45 2018
# (6815, 3)

# %%
X_test2.head(10)
# Out:
#         admission_type_id  payer_code  number_diagnoses  num_medications  \
# 70355                   0          15                 8               14
# 71086                   1           7                 9               22
# 93295                   0           8                 9               14
# 4572                    0           0                 7                9
# 18532                   0           0                 9               26
# 49431                   0           0                 4               15
# 100818                  2           0                 9               17
# 65361                   0           1                 6                5
# 94624                   0           7                 8               17
# 5018                    0           0                 9               25
#
#         admission_source_id  num_lab_procedures  A1Cresult  time_in_hospital  \
# 70355                     6                  48          1                 2
# 71086                     6                  74          2                 6
# 93295                     6                  30          2                 6
# 4572                      6                  59          2                 3
# 18532                     6                  73          2                 8
# 49431                     6                  37          2                 2
# 100818                    0                  30          2                 3
# 65361                     6                  43          2                 1
# 94624                     6                  42          1                 6
# 5018                      6                  63          2                11
#
#         number_inpatient  discharge_disposition_id   ...    age  \
# 70355                  0                         0   ...      7
# 71086                  5                         0   ...      8
# 93295                  1                         0   ...      4
# 4572                   3                         5   ...      7
# 18532                  2                        17   ...      6
# 49431                  0                         0   ...      7
# 100818                 2                         0   ...      6
# 65361                  0                         0   ...      4
# 94624                  6                         0   ...      5
# 5018                   8                         5   ...      4
#
#         medical_specialty  race  number_outpatient  insulin  number_emergency  \
# 70355                   0     3                  0        3                 0
# 71086                   7     3                  1        1                 1
# 93295                   0     1                  0        1                 3
# 4572                   17     3                  0        2                 0
# 18532                   0     4                  0        1                 0
# 49431                   0     3                  0        1                 0
# 100818                  0     3                  0        3                 0
# 65361                   4     3                  0        1                 0
# 94624                   0     3                  0        2                 5
# 5018                    0     1                  0        3                 1
#
#         num_procedures  diag_2  diag_3  diag_1
# 70355                0     207     573     205
# 71086                0      34      59     444
# 93295                0      87     159     111
# 4572                 0     205     195     213
# 18532                5     208     257     198
# 49431                1     498      59     463
# 100818               0      12     423     123
# 65361                0     187      59     431
# 94624                0     412     104      69
# 5018                 2     189     265     319
#
# [10 rows x 22 columns]

# %%
def intersect(a, b):
    return list(set(a) & set(b))
def union(a, b):
    return list(set(a) | set(b))
def subtract(a, b):
    return list(set(a) - set(b))

# %% [markdown]
# #### Now let's go to One-Hot Encoding to try other algorithms

# %%
# separate the categorical from non-categorical

categoricals2 = intersect(X_train2.columns, categoricals)
non_categoricals = subtract(X_train2.columns, categoricals)

print categoricals2
print non_categoricals
# Out:
# ['gender', 'age', 'A1Cresult', 'admission_source_id', 'medical_specialty', 'payer_code', 'race', 'diag_2', 'insulin', 'diag_1', 'discharge_disposition_id', 'diag_3', 'change', 'admission_type_id']
# ['number_emergency', 'time_in_hospital', 'number_diagnoses', 'num_lab_procedures', 'number_outpatient', 'num_medications', 'number_inpatient', 'num_procedures']

# %% [markdown]
# #### If they are numerical (non-catigorical) use Standard Scaler
# #### if they are categorical, use On-Hot Encoding
# #### Then combine all columns back together

# %%
# Split out categoricals and numeric columns and handle separately

X_train3_cat = X_train2[categoricals2] 
X_test3_cat = X_test2[categoricals2] 
X_train3_num = X_train2[non_categoricals] 
X_test3_num = X_test2[non_categoricals] 


# Scale without categoricals
scaler = preprocessing.StandardScaler() 
scaler.fit(X_train3_num)
X_train3_num = scaler.transform(X_train3_num)
X_test3_num = scaler.transform(X_test3_num)

encoder =  preprocessing.OneHotEncoder( categorical_features='all', sparse=False)

# TODO: I dont like this it needs the test data for encoding due to unknown values
X_all_cat = pd.concat([X_train3_cat, X_test3_cat])
encoder.fit(X_all_cat)
X_train3_cat = encoder.transform(X_train3_cat)
X_test3_cat = encoder.transform(X_test3_cat)


# recombine categorical and numeric columns into one big numpy array
X_train3 = np.concatenate((X_train3_num, X_train3_cat), axis = 1 )
X_test3 = np.concatenate((X_test3_num, X_test3_cat), axis = 1 )


print np.shape(X_train3)
print X_train3
print np.shape(X_test3)
print X_test3
# Out:
# (15899, 1836)
# [[-0.23081791  3.14060768  0.78069765 ...,  0.          0.          0.        ]
#  [-0.23081791 -0.8431582  -0.28946763 ...,  0.          0.          0.        ]
#  [-0.23081791  0.15278327 -0.82455026 ...,  0.          0.          0.        ]
#  ...,
#  [-0.23081791 -0.17919722  0.78069765 ...,  0.          0.          0.        ]
#  [-0.23081791 -0.8431582  -1.3596329  ...,  1.          0.          0.        ]
#  [-0.23081791  1.48070523  0.78069765 ...,  0.          0.          0.        ]]
# (6815, 1836)
# [[-0.23081791 -0.8431582   0.24561501 ...,  0.          0.          0.        ]
#  [ 0.64838044  0.48476376  0.78069765 ...,  0.          0.          0.        ]
#  [ 2.40677713  0.48476376  0.78069765 ...,  0.          0.          0.        ]
#  ...,
#  [-0.23081791 -0.51117771 -1.3596329  ...,  0.          0.          0.        ]
#  [-0.23081791  1.48070523  0.78069765 ...,  0.          0.          0.        ]
#  [ 0.64838044  0.15278327  0.78069765 ...,  0.          0.          0.        ]]

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Let's try again, this time using Ensemble Learning</b><br>
# 1. Train a number of different algorithms on the same data, or variations of the same data<br>
# 2. Run predictions for each trained model<br>
# 3. Average the results of all the different algorithms <br>
# 4. Use the averages as the new predictions.<br>
# 5. Determine accuracy of the ensemble.
# <br>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>ExtraTreesClassifier algorithm</b>  </div>

# %%
classifier = ExtraTreesClassifier(n_estimators=1000, max_features='auto', n_jobs=-1,  
                                  criterion='entropy',bootstrap=True, oob_score=True)
y_pred, y_probs = run_and_test_classifier(classifier, X_train3,y_train,X_test3, y_test)

df_ens['ExtraTrees3'] = y_probs
print np.shape(df_ens)
# Out:
# Start:  Mon Feb 12 04:53:22 2018
#
# ExtraTreesClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=-1,
#            oob_score=True, random_state=None, verbose=0, warm_start=False)
# Classification Results
#
#
# SCORE: ROC AUC
# ===========================================
# 0.671124395242
# Confusion Matrix
# ===========================================
# True Pos  	| False Neg
# 2135 		| 1287
# ------------------------------
# False Pos 	| True Neg
# 1287 		| 2106
#
#
#
# Classification Report
# ===========================================
#              precision    recall  f1-score   support
#
#           0       0.62      0.62      0.62      3422
#           1       0.62      0.62      0.62      3393
#
# avg / total       0.62      0.62      0.62      6815
#
#
#
#
#
# Feature Importances:
# ====================
#
#
#
# End:  Mon Feb 12 04:55:15 2018
# (6815, 4)

# %%
print np.shape(df_ens)
# Out:
# (6815, 4)

# %% [markdown]
# <div class="alert alert-block alert-success"><b>LogisticRegression Algorithm</b>  </div>

# %%
from  sklearn.linear_model import LogisticRegression

classifier = LogisticRegression(  penalty='l1', 
                                  dual=False, 
                                  tol=0.000001, C=1.0, 
                                  fit_intercept=True, 
                                  intercept_scaling=1, 
                                  class_weight=None, 
                                  random_state=None, 
                                  solver='liblinear', 
                                  max_iter=1000, 
                                  multi_class='ovr', 
                                  verbose=0, 
                                  warm_start=False, 
                                  n_jobs=-1)
y_pred, y_probs = run_and_test_classifier(classifier, X_train3,y_train,X_test3, y_test)

df_ens['Logistic'] = y_probs
print np.shape(df_ens)
# Out:
# Start:  Mon Feb 12 04:55:29 2018
#
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=1000, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=1e-06,
#           verbose=0, warm_start=False)
# Classification Results
#
#
# SCORE: ROC AUC
# ===========================================
# 0.665210097524
# Confusion Matrix
# ===========================================
# True Pos  	| False Neg
# 2244 		| 1178
# ------------------------------
# False Pos 	| True Neg
# 1406 		| 1987
#
#
#
# Classification Report
# ===========================================
#              precision    recall  f1-score   support
#
#           0       0.61      0.66      0.63      3422
#           1       0.63      0.59      0.61      3393
#
# avg / total       0.62      0.62      0.62      6815
#
#
#
#
#
# Feature Importances:
# ====================
#
#
#
# End:  Mon Feb 12 04:55:32 2018
# (6815, 5)

# %% [markdown]
# <div class="alert alert-block alert-success"><b>SGDC - Stochastic gradient descent algorithm</b>  </div>

# %%
from  sklearn.linear_model import SGDClassifier

classifier = SGDClassifier(loss='log', 
                           penalty='elasticnet', 
                           alpha=0.0001, 
                           l1_ratio=0.15, 
                           fit_intercept=True, 
                           max_iter=1000, 
                           tol = 0.000001,
                           shuffle=True, 
                           verbose=0, 
                           epsilon=0.1, 
                           n_jobs=-1, 
                           random_state=None, 
                           learning_rate='optimal', 
                           eta0=0.0, 
                           power_t=0.5, 
                           class_weight=None, 
                           warm_start=False, 
                           average=False)
y_pred, y_probs = run_and_test_classifier(classifier, X_train3,y_train,X_test3, y_test)

df_ens['SGD'] = y_probs
print np.shape(df_ens)
# Out:
# Start:  Mon Feb 12 04:55:40 2018
#
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', max_iter=1000, n_iter=None,
#        n_jobs=-1, penalty='elasticnet', power_t=0.5, random_state=None,
#        shuffle=True, tol=1e-06, verbose=0, warm_start=False)
# Classification Results
#
#
# SCORE: ROC AUC
# ===========================================
# 0.643072864802
# Confusion Matrix
# ===========================================
# True Pos  	| False Neg
# 1444 		| 1978
# ------------------------------
# False Pos 	| True Neg
# 820 		| 2573
#
#
#
# Classification Report
# ===========================================
#              precision    recall  f1-score   support
#
#           0       0.64      0.42      0.51      3422
#           1       0.57      0.76      0.65      3393
#
# avg / total       0.60      0.59      0.58      6815
#
#
#
#
#
# Feature Importances:
# ====================
#
#
#
# End:  Mon Feb 12 04:55:45 2018
# (6815, 6)

# %% [markdown]
# <div class="alert alert-block alert-success"><b>AdaBoostClassifier algorithm</b>  </div>

# %%
# Using Dense not oneHotEncoded X_train2 with AdaBoostClassifier

from sklearn.ensemble import AdaBoostClassifier
classifier = AdaBoostClassifier(n_estimators=300, learning_rate=0.9)
y_pred, y_probs = run_and_test_classifier(classifier, X_train2,y_train,X_test2, y_test)

df_ens['AdaBoost'] = y_probs
print np.shape(df_ens)
# Out:
# Start:  Mon Feb 12 04:56:11 2018
#
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=0.9, n_estimators=300, random_state=None)
# Classification Results
#
#
# SCORE: ROC AUC
# ===========================================
# 0.665875768226
# Confusion Matrix
# ===========================================
# True Pos  	| False Neg
# 2264 		| 1158
# ------------------------------
# False Pos 	| True Neg
# 1457 		| 1936
#
#
#
# Classification Report
# ===========================================
#              precision    recall  f1-score   support
#
#           0       0.61      0.66      0.63      3422
#           1       0.63      0.57      0.60      3393
#
# avg / total       0.62      0.62      0.62      6815
#
#
#
#
#
# Feature Importances:
# ====================
#
#
# admission_type_id    	         0.0
# payer_code           	  0.0133333333333
# number_diagnoses     	  0.0166666666667
# num_medications      	  0.0433333333333
# admission_source_id  	        0.01
# num_lab_procedures   	  0.0466666666667
# A1Cresult            	  0.00333333333333
# time_in_hospital     	        0.02
# number_inpatient     	  0.0433333333333
# discharge_disposition_id 	  0.283333333333
# change               	  0.00333333333333
# gender               	         0.0
# age                  	        0.02
# medical_specialty    	        0.05
# race                 	        0.01
# number_outpatient    	  0.0366666666667
# insulin              	  0.0166666666667
# number_emergency     	        0.03
# num_procedures       	  0.00333333333333
# diag_2               	  0.133333333333
# diag_3               	  0.113333333333
# diag_1               	  0.103333333333
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="90363c98-c73e-4848-b973-99d2046201e5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("90363c98-c73e-4848-b973-99d2046201e5");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("90363c98-c73e-4848-b973-99d2046201e5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '90363c98-c73e-4848-b973-99d2046201e5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7e1a87a9-2488-4c2a-a479-a94cb58a8a5b":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Feature":["num_lab_procedures"],"chart_index":[{"Feature":"num_lab_procedures"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.04666666666666667],"label":[{"Feature":"num_lab_procedures"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["num_lab_procedures"],"y":[0.023333333333333334]}},"id":"bd2a08c3-c868-4126-b32f-75c7bc552b40","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"01cf48da-3dd6-4692-b0d3-4980ccc8ecc1","subtype":"Chart","type":"Plot"},"ticker":{"id":"4de1321f-5459-4329-afb7-812712b58b28","type":"BasicTicker"}},"id":"af7df486-1011-4d97-881e-ba3ccbdf0405","type":"Grid"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Feature":["admission_type_id"],"chart_index":[{"Feature":"admission_type_id"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":[{"Feature":"admission_type_id"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["admission_type_id"],"y":[0.0]}},"id":"88dc485e-f721-45c3-a443-335231e9526f","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Feature":["number_emergency"],"chart_index":[{"Feature":"number_emergency"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.03],"label":[{"Feature":"number_emergency"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["number_emergency"],"y":[0.015]}},"id":"688714dd-9fe2-496e-8315-a2d219c6c41a","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Feature":["payer_code"],"chart_index":[{"Feature":"payer_code"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.013333333333333334],"label":[{"Feature":"payer_code"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["payer_code"],"y":[0.006666666666666667]}},"id":"a3bd6d28-6ec0-4253-942b-9ebf9eaf4124","type":"ColumnDataSource"},{"attributes":{},"id":"6fa470ea-a5fc-4d54-9f5b-dd6ac8d7ac85","type":"CategoricalTicker"},{"attributes":{"data_source":{"id":"2ce3320c-d7d0-446b-8e67-2eb639c693e2","type":"ColumnDataSource"},"glyph":{"id":"0c6a7cbe-e7f5-43e5-a126-351874aded90","type":"Rect"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"3236bf91-7267-4f80-a22a-95628c0c264c","type":"CDSView"}},"id":"bb24a25d-4b8d-4d8e-85ce-41383744be12","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Feature":["gender"],"chart_index":[{"Feature":"gender"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":[{"Feature":"gender"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["gender"],"y":[0.0]}},"id":"b5a7d1f9-2e2c-4ac3-8db1-56649c53f718","type":"ColumnDataSource"},{"attributes":{"source":null},"id":"02de8d99-4b9a-44a3-9448-ed573ed62799","type":"CDSView"},{"attributes":{"data_source":{"id":"f9db5854-6f3c-4da0-974c-393ef4478cfe","type":"ColumnDataSource"},"glyph":{"id":"eadb19fb-b522-4aa5-a57b-af7f99dbc507","type":"Rect"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"a7a8bbc5-0564-42dc-8658-f73a0f0d2d24","type":"CDSView"}},"id":"894d2b6d-81cc-4a24-b6a2-178469bb4b44","type":"GlyphRenderer"},{"attributes":{"source":null},"id":"a7a8bbc5-0564-42dc-8658-f73a0f0d2d24","type":"CDSView"},{"attributes":{"data_source":{"id":"481db6f4-57b2-473c-9f5d-fd1eaaf4be91","type":"ColumnDataSource"},"glyph":{"id":"d68cb3f8-419b-4711-a8cf-b958953144bc","type":"Rect"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"c8c3fead-0907-4b2b-aafc-3363ac871435","type":"CDSView"}},"id":"72d83fb0-048c-46f1-b74d-dd ...
# End:  Mon Feb 12 04:56:17 2018
# (6815, 7)

# %%
print df_ens.head(10)
# Out:
#    DecisionTree  ExtraTrees1  ExtraTrees2  ExtraTrees3  Logistic       SGD  \
# 0             0        0.526        0.458        0.374  0.587737  0.665249
# 1             1        0.730        0.753        0.622  0.693932  0.661318
# 2             1        0.614        0.642        0.561  0.500588  0.509235
# 3             0        0.588        0.592        0.628  0.824049  0.843996
# 4             1        0.754        0.698        0.670  0.669898  0.800289
# 5             0        0.194        0.213        0.307  0.403715  0.637289
# 6             1        0.716        0.671        0.528  0.673930  0.781292
# 7             0        0.154        0.197        0.190  0.172552  0.208107
# 8             0        0.766        0.766        0.650  0.767100  0.556562
# 9             1        0.832        0.821        0.764  0.959351  0.946577
#
#    AdaBoost
# 0  0.499751
# 1  0.501134
# 2  0.500221
# 3  0.501009
# 4  0.500933
# 5  0.499603
# 6  0.500768
# 7  0.498807
# 8  0.501365
# 9  0.502306

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Average the results of all the different algorithms </b>  </div>

# %%
if 'DecisionTree' in df_ens.columns:
    del df_ens['DecisionTree']

if 'SGD' in df_ens.columns:
    del df_ens['SGD']

ens = df_ens.mean(axis=1)

print 'Overall AUC: ', metrics.roc_auc_score(y_test, ens.values)
print
print
for c in df_ens.columns:
    p = (df_ens[c]).values
    print c.ljust(30), '\t',metrics.roc_auc_score(y_test, p)
    


plot_roc(y_test, ens.values)
# Out:
# Overall AUC:  0.675681341394
#
#
# ExtraTrees1                    	0.641141050359
# ExtraTrees2                    	0.653413024339
# ExtraTrees3                    	0.671124395242
# Logistic                       	0.665210097524
# AdaBoost                       	0.665875768226
# SCORE: ROC AUC
# ===========================================
# 0.675681341394

# %% [markdown]
# <div class="alert alert-block alert-warning"><b> How good model results are? </b><br><br>  __[A comparison of models for predicting early hospital readmissions](https://www.sciencedirect.com/science/article/pii/S1532046415000969
# )__  </div>
#
# <div class="alert alert-block alert-info"><b>(4) Store Model to Watson Machine Learning repository</b><br></div>
# <div class="alert alert-block alert-info"><b>(5) Model Deployment</b><br></div>
# <div class="alert alert-block alert-info"><b>(6) Continious Learning System Configuration</b><br></div>
#
# DASH FEEDBACK STORAGE : https://dashdb-entry-yp-dal10-01.services.dal.bluemix.net/dashdb/dashboard
